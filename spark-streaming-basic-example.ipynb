# %%
from pyspark import SparkContext
from pyspark.streaming import StreamingContext

# %%
spark = SparkContext('local[2]','word-count')
stream=StreamingContext(spark,1)

# %%
lines = stream.socketTextStream('localhost',9999)

# %%
df = spark.parallelize(range(1,100),4)

spark.defaultParallelism
# Out:
# 2

# %%
words = lines.flatMap(lambda line : line.split(' '))
pairs = words.map(lambda word: (word,1))

# %%
word_count = pairs.reduceByKey(lambda num1,num2: num1+num2)

# %%
word_count.pprint()

# %%
stream.start() # nc -lk 9999
# Out:
# -------------------------------------------
# Time: 2019-01-16 07:43:44
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-01-16 07:43:45
# -------------------------------------------
# ('kelo', 2)
# ('name', 2)
# ('is', 2)
# ('prasanna', 1)
# ('', 1)
# ('hello', 3)
# ('my', 2)
# ('and', 1)
# ('wife', 1)
# ('shruthi', 1)
#
# -------------------------------------------
# Time: 2019-01-16 07:43:46
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-01-16 07:43:47
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-01-16 07:43:48
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-01-16 07:43:49
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-01-16 07:43:50
# -------------------------------------------
#
# ...

# %%
stream.stop()
# Out:
# -------------------------------------------
# Time: 2019-01-16 07:45:46
# -------------------------------------------

# %%
import matplotlib
